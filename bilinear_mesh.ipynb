# %%
# %pylab inline
import bilinear_mesh
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
path = "/mnt/recover/leo/UofA_PD/fargo3d/outputs/fargo/"

# %%
phimin = loadtxt(path+"domain_x.dat")
rmin   = loadtxt(path+"domain_y.dat")[3:-3]

nx = 384
ny = 128

# %%
rmed = 0.5*(rmin[1:]+rmin[:-1])
phimed = 0.5*(phimin[1:]+phimin[:-1])
xplanet=1
yplanet=0

# %%
P,R=meshgrid(phimed,rmed)
X  = R*cos(P)-xplanet
Y  = R*sin(P)-yplanet

# %%
dens = fromfile(path+"gasdens10_new.dat").reshape(ny,nx)

# %%
pcolormesh( X, Y, log10(dens))
xlim(-0.2,0.2)
ylim(-0.2,0.2)
# Out:
# /tmp/ipykernel_64316/3504364710.py:1: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcolormesh( X, Y, log10(dens))
# (-0.2, 0.2)

# %%
imRHO, extent, new_p, new_r = bilinear_mesh.get_polar(0., 0.15, -pi, pi, rmed, phimed , dens, 128,128)

# %%
extent
# Out:
# [-3.141592653589793, 3.141592653589793, 0.15, 0.0]

# %%
imshow(log10(imRHO), extent=extent, aspect='auto')
